# %%
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv('OPENAPI_API_KEY')

# %%
import requests  #웹페이지의 내용(html)을 쉽게 가지고 오도록 해주는 라이브러리
import json

# .strip()--> 양쪽 공백을 제거

print(f'APIKEY 길이 : {len(API_KEY)}')
print(f'앞 10자리 : {API_KEY[:10]}...')
# Out:
# APIKEY 길이 : 64
# 앞 10자리 : 99c2b74393...
