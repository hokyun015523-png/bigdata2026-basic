# %% [markdown]
# # 대구 달서구  cctv갯수

# %% [markdown]
# imp

# %%
import csv

with open('cctv_20250527.csv', 'rt') as f:
    buffer = csv.reader(f, delimiter=',')
    totalcctv = 0 # cctv 갯수
    for i in buffer:
        totalcctv += int(i[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 7
#       3 with open('cctv_20250527.csv', 'rt') as f:
#       4     buffer = csv.reader(f, delimiter=',')
#       5     totalcctv = 0 # cctv 갯수
#       6     for i in buffer:
# ----> 7         totalcctv += int('i'[6])
#       8
#       9
#
# IndexError: string index out of range

# %%
buffer

# %%
for i in buffer:
    totalcctv += int(i[6])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for i in buffer:
#       2     totalcctv += int(i[6])
#
# ValueError: I/O operation on closed file.

# %%
import csv

with open('cctv_20250527.csv', 'rt') as f:
    buffer = csv.reader(f, delimiter=',')
    totalcctv = 0 # cctv 갯수
    for i, line in enumerate(buffer):
        if i !=0:
            totalcctv += int(line[6])

# %%
buffer

# %%
totalcctv
# Out:
# 2900

# %%
# with open('CCTV_20250527.csv', 'rt') as f:
#     f.readlin()
#     totalcctv =0
#     while True:
#         line = f.readline()
#         if not line:
#             break
#         result = line.split(',')
#         totalcctv += int(result[6])
